# %% [markdown]
# <center>
# <a href="http://www.insa-toulouse.fr/" ><img src="http://www.math.univ-toulouse.fr/~besse/Wikistat/Images/logo-insa.jpg" style="float:left; max-width: 120px; display: inline" alt="INSA"/></a>
# <a href="http://wikistat.fr/" ><img src="http://www.math.univ-toulouse.fr/~besse/Wikistat/Images/wikistat.jpg" style="max-width: 150px; display: inline"  alt="Wikistat"/></a>
# <a href="http://www.math.univ-toulouse.fr/" ><img src="http://www.math.univ-toulouse.fr/~besse/Wikistat/Images/logo_imt.jpg" width=400,  style="float:right;  display: inline" alt="IMT"/> </a>
#
# </center>

# %% [markdown]
# # High Dimensional & Deep Learning : Image classification  on MNIST dataset.

# %% [markdown]
# ## Objectives
# In this TP you will learn to :
# * Write multilayer perceptron and convolutional network with `Keras`and `Tensorflow`
# * Understand how `convolutional`, `max pooling`, `stride` and `padding`layers work.
# * Use these models for image classification.

# %% [markdown]
# ## Libraries

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
import seaborn as sb
sb.set()

import pandas as pd
import numpy as np
import time

import tensorflow.keras.utils as ku
import tensorflow.keras.models as km
import tensorflow.keras.layers as kl
import tensorflow.keras.optimizers as ko
import tensorflow.keras.preprocessing.image as k


from sklearn.metrics import confusion_matrix

# %%
import tensorflow
tensorflow.__version__
# Out:
# '2.4.1'

# %% [markdown]
# This code lines allow you to check if your computer is using CPU or GPU ressources. <br>
# **Warning** : You won't be able to use GPU if another notebook is open and still uses GPU.

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 14591105416875247036
# ]
# 2022-09-27 14:12:12.746445: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Dataset

# %% [markdown]
# The dataset that will be used in this TP is the [MNIST DataBase](http://yann.lecun.com/exdb/mnist/).<br>
# It is composed of 70.000 images (60.000 for learning, 10.000 for test) of 28x28 pixels of handwritten digits from 0 to 9.<br>
#
# These data are directly available on the `Keras` library.

# %%
from tensorflow.keras.datasets import mnist

(X_train, Y_train), (X_test, Y_test) = mnist.load_data()
N_train, N_x_pixels, N_y_pixels = X_train.shape
N_test = X_test.shape[0]
N_classes = len(set(Y_train))

print("Train data : %d images  (%d/%d pixels)" %(N_train, N_x_pixels, N_y_pixels))
print("Test data : %d images  (%d/%d pixels)" %(N_test, N_x_pixels, N_y_pixels))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 1s 0us/step
# Train data : 60000 images  (28/28 pixels)
# Test data : 10000 images  (28/28 pixels)

# %%
sample_index = 45
fig =plt.figure(figsize=(3, 3))
ax = fig.add_subplot(1,1,1)
ax.imshow(X_train[sample_index], cmap=plt.cm.gray_r, interpolation='nearest')
ax.set_title("image label: %d" % Y_train[sample_index])
ax.grid(False)
ax.axis('off')
plt.show()

# %% [markdown]
# ### Image example

# %% [markdown]
# ## Image classification with Multi Layer Perceptron model.

# %% [markdown]
# We will first try to learn an image classifier with a MLP model with the following architecture.
#
# * A Dense layer with 128 neurons and *relu* activation function
# * A Dropout Layer with 20% drop rate
# * A Dense layer with 128 neurons and *relu* activation function
# * A Dropout Layer with 20% drop rate
# * A Dense layer with 10 neurons (Number of classes ) and *softmax* activation function

# %% [markdown]
# ### Data format
#
# Some modifications are required on the data to use them with our model.
#
# The first layer is a Dense Layer, which handles 1D vectors as an input. We must first reshape the 2D 28x28 images as a 1D $28*28=784$ vector.

# %%
X_train_flatten = X_train.reshape((N_train, N_x_pixels*N_y_pixels))/255
X_test_flatten = X_test.reshape((N_test, N_x_pixels*N_y_pixels))/255
N_dim_flatten = X_train_flatten.shape[1]
print("Dimensions of flatten train images : %d X %d" %(X_train_flatten.shape))
print("Dimensions of flatten test images : %d X %d" %(X_test_flatten.shape))
# Out:
# Dimensions of flatten train images : 60000 X 784
# Dimensions of flatten test images : 10000 X 784

# %% [markdown]
# ### Architecture

# %%
# Définition du réseau
model = km.Sequential()
model.add(kl.Dense(128, activation='relu', input_shape=(N_dim_flatten,)))
model.add(kl.Dropout(0.2))
model.add(kl.Dense(128, activation='relu'))
model.add(kl.Dropout(0.2))
model.add(kl.Dense(N_classes, activation='softmax'))
# Réumé
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________
# 2022-09-27 14:19:24.311405: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-09-27 14:19:24.315269: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %% [markdown]
# **Q** The summary displays the number of pararameters/weigths of the model. Retrieve these values with the formulas seen in the course.
#
# - dense: 784*128+128
# - dense_1 : 128*128+128
# - dense_2 : 128*10+10
#
# Couche dropout : utile que pendant l'entrainement car ajoute de l'aléa et pour le test on ne veut pas quelque chose d'aléatoire. Le dropout éteint aléatoirement des neurones à chaque passage dans le réseau, mais on prend quand même en compte tous les neurones pour le calcul du nombre de paramètres.

# %% [markdown]
# ### Training

# %% [markdown]
# You will now instantiate your model by defining :
# * An optimizer : `RMSprop`
# * a loss function : `Categorical crossentropy`
# * Metric : This argument is an option, it allows to compute the metric if you want to check the evolution of the training. Here we choose to compute the accuracy during the training.
#
# **Note** : In Keras you can choose either "sparse_categorical_crossentropy" or "categorical_crossentropy" loss. The former handles 1D (NX1) vectors where each entry contains the label of the data, i.e [0,3,5,9,3,4,...]. The latter handles only one-hot encoding of this vector, ie  2D vectors (NXN_classes) matrices. Keras has a `to_categorical` function which allows to convert a vector to its one-hot encoding representation.

# %%
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=ko.RMSprop(),
              metrics=['accuracy'])

# %%
#X_train_flatten[0] déjà normalisé

# %%
batch_size = 256
epochs=10
ts = time.time()
history = model.fit(X_train_flatten, Y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(X_test_flatten, Y_test))
te = time.time()
t_train_mpl = te-ts
# Out:
# 2022-09-27 14:31:00.656295: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-09-27 14:31:00.688362: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 3199980000 Hz
# Epoch 1/10
# 235/235 [==============================] - 5s 16ms/step - loss: 0.7279 - accuracy: 0.7837 - val_loss: 0.2129 - val_accuracy: 0.9368
# Epoch 2/10
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2182 - accuracy: 0.9344 - val_loss: 0.1286 - val_accuracy: 0.9602
# Epoch 3/10
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1534 - accuracy: 0.9539 - val_loss: 0.1078 - val_accuracy: 0.9689
# Epoch 4/10
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1232 - accuracy: 0.9629 - val_loss: 0.1001 - val_accuracy: 0.9702
# Epoch 5/10
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1050 - accuracy: 0.9676 - val_loss: 0.0914 - val_accuracy: 0.9735
# Epoch 6/10
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0899 - accuracy: 0.9719 - val_loss: 0.0876 - val_accuracy: 0.9741
# Epoch 7/10
# 235/235 [==============================] - 2s 6ms/step - loss: 0.0831 - accuracy: 0.9743 - val_loss: 0.0774 - val_accuracy: 0.9770
# Epoch 8/10
# 235/235 [==============================] - 2s 6ms/step - loss: 0.0717 - accuracy: 0.9781 - val_loss: 0.0788 - val_accuracy: 0.9773
# Epoch 9/10
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0657 - accuracy: 0.9799 - val_loss: 0.0709 - val_accuracy: 0.9801
# Epoch 10/10
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0632 - accuracy: 0.9803 - val_loss: 0.0688 - val_accuracy: 0.9801

# %% [markdown]
# ### Results

# %%
score_mpl = model.evaluate(X_test_flatten, Y_test, verbose=0)
predict_mpl = model.predict(X_test_flatten)
print('Test loss:', score_mpl[0])
print('Test accuracy:', score_mpl[1])
print("Time Running: %.2f seconds" %t_train_mpl )
fig=plt.figure(figsize=(7,6))
ax = fig.add_subplot(1,1,1)
ax = sb.heatmap(pd.DataFrame(confusion_matrix(Y_test, predict_mpl.argmax(1))), annot=True, fmt="d")
# Out:
# Test loss: 0.06877550482749939
# Test accuracy: 0.9800999760627747
# Time Running: 18.86 seconds

# %% [markdown]
# **Question** What can you say about these results?
#
# Ce sont de bons résultats
#
# **Exercise** Normalize the data in order to have values between 0 and 1 and run again the learning. What can you say about these results?
#
# Déjà normalisé avec le division par 255 au dessus

# %% [markdown]
# ## Convolutional Layers
#
# In this part we will use convolution layers to build a convolutional classifier.

# %% [markdown]
# **Data**
#
# The convolution architecture takes as input images and not 1D vectors. However, some data formating are still required.
#
# A third dimension is required : the `channels` dimension which will allow to describe each pixel. In our case this dimension's size is only 1 because the images are only defined with grey scale. However for colour images, each pixel is coded with several values (Images are generally encoded with 3 values (RGB channels)).
#
# Hence, we need to reshape the images from a 28x28 dimension to a 28X28X1 dimension

# %%
X_train_conv = np.expand_dims(X_train,axis=-1)
X_test_conv = np.expand_dims(X_test,axis=-1)
X_train_conv.shape

#nbre d'images (nb batchs), 1ere dim image, 2eme dim image, nb channels
# Out:
# (60000, 28, 28, 1)

# %% [markdown]
# ### Edge detection
#
# We will first check the transformation applied by a convolution layer.
#
# In the following code, we define a convolutional network with  only one filter for which we manually define the weights.

# %%
conv_filter = np.array([
        [0.2, -0.2, 0],
        [0.2, -0.2, 0],
        [0.2, -0.2, 0],
    ])

#conv_filter=conv_filter.T

def my_init_filter(shape, conv_filter = conv_filter, dtype=None, partition_info=None):
    xf,yf = conv_filter.shape
    array = conv_filter.reshape(xf, yf, 1, 1)
    return array
my_init_filter(0).shape

conv_edge = km.Sequential([
    kl.Conv2D(kernel_size=(3,3), filters=1, kernel_initializer=my_init_filter, input_shape=(28, 28, 1))   
])

# %% [markdown]
#  **Q** Note that in  `my_init_filter` two dimensions have been added to the conv filter. What do these dimensions represent?
#
#  1 seul canal, 1 seul filtre
#
#  The following code allows to display the image, the filter and the convoluted image.

# %%
x = X_train_conv[0]
img_in = np.expand_dims(x, 0)
img_out = conv_edge.predict(img_in)

fig, (ax0, ax1, ax2) = plt.subplots(ncols=3, figsize=(15, 5))
ax0.imshow(img_in[0,:,:,0], cmap="binary")
ax0.set_title("Image originale")
ax0.grid(False)

norm_conv_filter = (conv_filter-conv_filter.min())/conv_filter.max()
ax1.imshow(norm_conv_filter.astype(np.uint8), cmap="binary")
ax1.set_title("Filtre")
ax1.grid(False)

ax2.imshow(img_out[0,:,:,0].astype(np.uint8), cmap="binary")
ax2.set_title("Image Filtre")
ax2.grid(False)

# %% [markdown]
# **Q** What do you see? Are the output image coherent according to the designed filter ?
#
# On détecte les bordures verticales
#
# **Exercise** Change the code in order to test different filters (to detect horizontal edges, etc...)

# %% [markdown]
# ### Strides and Padding
#
# We will now study the effect on `strides` and `padding` arguments on the image.

# %%
conv_filter = np.array([
        [0, 0, 0],
        [0, 1, 0],
        [0, 0, 0],
    ])

def my_init_filter(shape, conv_filter = conv_filter, dtype=None, partition_info = None):
    xf,yf = conv_filter.shape
    array = conv_filter.reshape(xf, yf, 1, 1)
    return array
my_init_filter(0).shape

conv_sp = km.Sequential([
    kl.Conv2D(kernel_size=(3,3), filters=1, kernel_initializer=my_init_filter, input_shape=(28, 28, 1),
           strides=2, padding="SAME") ])

# %% [markdown]
# **Q** What is the effect of the convolutional filter defined here ?
#
# Floute l'image

# %%
img_in = np.expand_dims(x, 0)
img_out = conv_sp.predict(img_in)

fig, (ax0, ax1, ax2) = plt.subplots(ncols=3, figsize=(15, 5))
ax0.imshow(img_in[0,:,:,0].astype(np.uint8),
           cmap="binary");
ax0.grid(False)

norm_conv_filter = (conv_filter-conv_filter.min())/conv_filter.max()
ax1.imshow(norm_conv_filter.astype(np.uint8),
           cmap="binary");
ax1.grid(False)

ax2.imshow(img_out[0,:,:,0].astype(np.uint8),
           cmap="binary");
ax2.grid(False)
# Out:
# WARNING:tensorflow:7 out of the last 319 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fcf50020550> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# **Exercise** Check the dimension of the output images. Are they coherent? <br>
#
# Dimension deux fois plus petite car stride=2
#
# **Exercise** Change both *strides* and *padding* arguments and understand the effect of these changes.
#
# option padding : 'VALID' ou 'SAME'

# %% [markdown]
# ### Max Pooling

# %% [markdown]
# **Exercice** Write a similar code than above to check and understand the behaviour of the `max pooling` layer.

# %%
conv_filter = np.array([
        [0, 0, 0],
        [0, 1, 0],
        [0, 0, 0],
    ])

def my_init_filter(shape, conv_filter = conv_filter, dtype=None, partition_info = None):
    xf,yf = conv_filter.shape
    array = conv_filter.reshape(xf, yf, 1, 1)
    return array
my_init_filter(0).shape

conv_sp = km.Sequential([
    kl.Conv2D(kernel_size=(3,3), filters=1, kernel_initializer=my_init_filter, input_shape=(28, 28, 1),
           strides=2, padding="SAME"), 
kl.MaxPooling2D(pool_size=2, strides=1, padding='valid'
)])

# %%
img_in = np.expand_dims(x, 0)
img_out = conv_sp.predict(img_in)

fig, (ax0, ax1, ax2) = plt.subplots(ncols=3, figsize=(15, 5))
ax0.imshow(img_in[0,:,:,0].astype(np.uint8),
           cmap="binary");
ax0.grid(False)

norm_conv_filter = (conv_filter-conv_filter.min())/conv_filter.max()
ax1.imshow(norm_conv_filter.astype(np.uint8),
           cmap="binary");
ax1.grid(False)

ax2.imshow(img_out[0,:,:,0].astype(np.uint8),
           cmap="binary");
ax2.grid(False)
# Out:
# WARNING:tensorflow:11 out of the last 323 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fcf315871f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
# %load solutions/max_pooling.py
conv_mp = km.Sequential([ kl.MaxPool2D(pool_size=(2,2))])

img_in = np.expand_dims(x, 0)
img_out = conv_mp.predict(img_in)

fig, (ax0, ax1) = plt.subplots(ncols=2, figsize=(10, 5))
ax0.imshow(img_in[0,:,:,0].astype(np.uint8),
           cmap="binary");
ax0.grid(False)

ax1.imshow(img_out[0,:,:,0].astype(np.uint8),
           cmap="binary");
ax1.grid(False)
# Out:
# WARNING:tensorflow:9 out of the last 321 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fcf31587160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# **Questions** What are the dimension of the output image? Is this normal?
#
# MaxPooling fait passer un filtre de taille 2x2 et prend la valeur max donc divise la dimension par 2.

# %% [markdown]
# ## *Convolutional Network (ConvNet)*
#
# We will now build convolutional networks and see the performances on this kind of model on  image classification problems.

# %% [markdown]
# ### LeNet5
#
# We first test the  LeNet5 model, proposed by LeCun et al.

# %%
LeNet5model = km.Sequential()
LeNet5model.add(kl.Conv2D(filters = 6, kernel_size = 5, strides = 1, activation = 'tanh',
input_shape = (28,28,1)))
LeNet5model.add(kl.MaxPooling2D(pool_size = 2, strides = 2))
LeNet5model.add(kl.Conv2D(filters = 16, kernel_size = 5,strides = 1, activation = 'tanh'))
LeNet5model.add(kl.MaxPooling2D(pool_size = 2, strides = 2))
LeNet5model.add(kl.Flatten())
LeNet5model.add(kl.Dense(units = 120, activation = 'tanh'))
LeNet5model.add(kl.Dense(units = 84, activation = 'tanh'))
LeNet5model.add(kl.Dense(units = 10, activation = 'softmax'))

LeNet5model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_11 (Conv2D)           (None, 24, 24, 6)         156
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 12, 12, 6)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 8, 8, 16)          2416
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 4, 4, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 120)               30840
# _________________________________________________________________
# dense_4 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                850
# =================================================================
# Total params: 44,426
# Trainable params: 44,426
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Exercise** Retrieve 'manually' the number of parameters of this model.
#
# conv2d_11 : (f*f*c+1)*n --> (5*5*1+1)*6 = 156
#
# conv2d_12 : (5*5*1+1)*16 = (5*5*6+1)*16
#
# dense_3 : 256*120 + 120 = 30840
#
# dense_4 : 120*84 + 84 = 10164
#
# dense_5 : 84*10 + 10
#
# **Question** What can you say about the total number of parameters compared with the MLP model defined before? Which layer has the highest number of parameters?
#
# Beaucoup moins important

# %%
# Apprentissage
batch_size=128
epochs=30
LeNet5model.compile(loss="sparse_categorical_crossentropy",
              optimizer=ko.Adadelta(),
              metrics=['accuracy'])
ts=time.time()
LeNet5model.fit(X_train_conv, Y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(X_test_conv, Y_test))
te=time.time()
t_train_conv = te-ts
# Out:
# Epoch 1/30
# 469/469 [==============================] - 10s 20ms/step - loss: 2.3894 - accuracy: 0.0860 - val_loss: 2.3205 - val_accuracy: 0.1211
# Epoch 2/30
# 469/469 [==============================] - 13s 27ms/step - loss: 2.3023 - accuracy: 0.1357 - val_loss: 2.2449 - val_accuracy: 0.1900
# Epoch 3/30
# 469/469 [==============================] - 9s 19ms/step - loss: 2.2306 - accuracy: 0.2035 - val_loss: 2.1760 - val_accuracy: 0.2446
# Epoch 4/30
# 469/469 [==============================] - 13s 27ms/step - loss: 2.1632 - accuracy: 0.2521 - val_loss: 2.1103 - val_accuracy: 0.2968
# Epoch 5/30
# 469/469 [==============================] - 15s 33ms/step - loss: 2.1007 - accuracy: 0.3029 - val_loss: 2.0466 - val_accuracy: 0.3536
# Epoch 6/30
# 469/469 [==============================] - 7s 14ms/step - loss: 2.0369 - accuracy: 0.3542 - val_loss: 1.9841 - val_accuracy: 0.4034
# Epoch 7/30
# 469/469 [==============================] - 12s 26ms/step - loss: 1.9751 - accuracy: 0.4063 - val_loss: 1.9227 - val_accuracy: 0.4544
# Epoch 8/30
# 469/469 [==============================] - 11s 24ms/step - loss: 1.9143 - accuracy: 0.4500 - val_loss: 1.8624 - val_accuracy: 0.4969
# Epoch 9/30
# 469/469 [==============================] - 13s 28ms/step - loss: 1.8572 - accuracy: 0.4864 - val_loss: 1.8034 - val_accuracy: 0.5325
# Epoch 10/30
# 469/469 [==============================] - 15s 31ms/step - loss: 1.7948 - accuracy: 0.5270 - val_loss: 1.7453 - val_accuracy: 0.5629
# Epoch 11/30
# 469/469 [==============================] - 9s 19ms/step - loss: 1.7414 - accuracy: 0.5530 - val_loss: 1.6887 - val_accuracy: 0.5879
# Epoch 12/30
# 469/469 [==============================] - 8s 17ms/step - loss: 1.6860 - accuracy: 0.5751 - val_loss: 1.6332 - val_accuracy: 0.6113
# Epoch 13/30
# 469/469 [==============================] - 12s 25ms/step - loss: 1.6317 - accuracy: 0.6008 - val_loss: 1.5791 - val_accuracy: 0.6310
# Epoch 14/30
# 469/469 [==============================] - 12s 26ms/step - loss: 1.5807 - accuracy: 0.6222 - val_loss: 1.5267 - val_accuracy: 0.6508
# Epoch 15/30
# 469/469 [==============================] - 14s 30ms/step - loss: 1.5248 - accuracy: 0.6401 - val_loss: 1.4757 - val_accuracy: 0.6664
# Epoch 16/30
# 469/469 [==============================] - 11s 24ms/step - loss: 1.4756 - accuracy: 0.6579 - val_loss: 1.4262 - val_accuracy: 0.6802
# Epoch 17/30
# 469/469 [==============================] - 11s 24ms/step - loss: 1.4242 - accuracy: 0.6740 - val_loss: 1.3786 - val_accuracy: 0.6923
# Epoch 18/30
# 469/469 [==============================] - 13s 27ms/step - loss: 1.3838 - accuracy: 0.6839 - val_loss: 1.3326 - val_accuracy: 0.7069
# Epoch 19/30
# 469/469 [==============================] - 8s 18ms/step - loss: 1.3388 - accuracy: 0.6983 - val_loss: 1.2883 - val_accuracy: 0.7200
# Epoch 20/30
# 469/469 [==============================] - 11s 24ms/step - loss: 1.2905 - accuracy: 0.7142 - val_loss: 1.2459 - val_accuracy: 0.7306
# Epoch 21/30
# 469/469 [==============================] - 12s 26ms/step - loss: 1.2504 - accuracy: 0.7218 - val_loss: 1.2049 - val_accuracy: 0.7400
# Epoch 22/30
# 469/469 [==============================] - 15s 32ms/step - loss: 1.2124 - accuracy: 0.7312 - val_loss: 1.1657 - val_accuracy: 0.7506
# Epoch 23/30
# 469/469 [==============================] - 14s 29ms/step - loss: 1.1703 - accuracy: 0.7405 - val_loss: 1.1283 - val_accuracy: 0.7592
# Epoch 24/30
# 469/469 [==============================] - 10s 21ms/step - loss: 1.1294 - accuracy: 0.7529 - val_loss: 1.0928 - val_accuracy: 0.7664
# Epoch 25/30
# 469/469 [==============================] - 13s 28ms/step - loss: 1.0961 - accuracy: 0.7583 - val_loss: 1.0590 - val_accuracy: 0.7730
# Epoch 26/30
# 469/469 [==============================] - 16s 34ms/step - loss: 1.0685 - accuracy: 0.7621 - val_loss: 1.0267 - val_accuracy: 0.7787
# Epoch 27/30
# 469/469 [==============================] - 14s 29ms/step - loss: 1.0307 - accuracy: 0.7695 - val_loss: 0.9962 - val_accuracy: 0.7842
# Epoch 28/30
# 469/469 [==============================] - 12s 26ms/step - loss: 1.0038 - accuracy: 0.7736 - val_loss: 0.9674 - val_accuracy: 0.7880
# Epoch 29/30
# 469/469 [==============================] - 14s 30ms/step - loss: 0.9736 - accuracy: 0.7824 - val_loss: 0.9398 - val_accuracy: 0.7942
# Epoch 30/30
# 469/469 [==============================] - 12s 26ms/step - loss: 0.9439 - accuracy: 0.7879 - val_loss: 0.9137 - val_accuracy: 0.7980

# %% [markdown]
# **Q** Why is the training time longer?
#
# Plus de couches avec plusieurs convolutions avec plusieurs filtres
# Plus d'epochs

# %% [markdown]
# #### Results

# %%
score_conv = LeNet5model.evaluate(X_test_conv, Y_test, verbose=0)
predict_conv = LeNet5model.predict(X_test_conv)
print('Test loss:', score_conv[0])
print('Test accuracy:', score_conv[1])
print("Time Running: %.2f seconds" %t_train_conv )

fig=plt.figure(figsize=(7,6))
ax = fig.add_subplot(1,1,1)
ax = sb.heatmap(pd.DataFrame(confusion_matrix(Y_test, predict_conv.argmax(1))), annot=True, fmt="d")
# Out:
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fcf316bf8b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Test loss: 0.913727343082428
# Test accuracy: 0.7979999780654907
# Time Running: 359.12 seconds

# %% [markdown]
# ### A more complex architecture
#
# #### Network
#
# We will now design a more complex architecture to try to improve the results of the classification :
#
# * A Conv2D layer with 32-3X3 filters and the `Relu` activation function.
# * A Conv2D layer with 642-3X3 filters and the `Relu` activation function.
# * A MaxPooling layer with a 2X2 window.
# * A Dropout layer with a 25% drop rate.
# * A flatten layer.
# * A Dense layer with 128 neurons  and the `Relu` activation function.
# * A Dropout layer with a 50% drop rate.
# * A Dense layer with 10 neurons  and the `softmax` activation function.
#
#
# **Exercise** Define this model and train it.

# %%
newmodel = km.Sequential()
newmodel.add(kl.Conv2D(filters = 32, kernel_size = 3, strides = 1, activation = 'relu',
input_shape = (28,28,1)))
newmodel.add(kl.Conv2D(filters = 642, kernel_size = 3,strides = 1, activation = 'relu'))
newmodel.add(kl.MaxPooling2D(pool_size = 2, strides = 2))
newmodel.add(kl.Dropout(0.25))
newmodel.add(kl.Flatten())
newmodel.add(kl.Dense(units = 128, activation = 'relu'))
newmodel.add(kl.Dropout(0.5))
newmodel.add(kl.Dense(units = 10, activation = 'softmax'))

newmodel.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_15 (Conv2D)           (None, 26, 26, 32)        320
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 24, 24, 642)       185538
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 12, 12, 642)       0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 12, 12, 642)       0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 92448)             0
# _________________________________________________________________
# dense_8 (Dense)              (None, 128)               11833472
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 12,020,620
# Trainable params: 12,020,620
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Apprentissage
batch_size=128
epochs=10
newmodel.compile(loss="sparse_categorical_crossentropy",
              optimizer=ko.Adadelta(),
              metrics=['accuracy'])
ts=time.time()
newmodel.fit(X_train_conv, Y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(X_test_conv, Y_test))
te=time.time()
t_train_conv = te-ts
# Out:
# Epoch 1/10
# 469/469 [==============================] - 369s 785ms/step - loss: 3.1059 - accuracy: 0.3578 - val_loss: 0.7094 - val_accuracy: 0.8257
# Epoch 2/10
# 469/469 [==============================] - 365s 779ms/step - loss: 1.1143 - accuracy: 0.6389 - val_loss: 0.4224 - val_accuracy: 0.8924
# Epoch 3/10
# 469/469 [==============================] - 380s 810ms/step - loss: 0.8474 - accuracy: 0.7331 - val_loss: 0.3405 - val_accuracy: 0.9125
# Epoch 4/10
# 469/469 [==============================] - 382s 814ms/step - loss: 0.7045 - accuracy: 0.7793 - val_loss: 0.2775 - val_accuracy: 0.9254
# Epoch 5/10
# 469/469 [==============================] - 375s 801ms/step - loss: 0.6196 - accuracy: 0.8101 - val_loss: 0.2476 - val_accuracy: 0.9319
# Epoch 6/10
# 469/469 [==============================] - 368s 786ms/step - loss: 0.5712 - accuracy: 0.8281 - val_loss: 0.2222 - val_accuracy: 0.9394
# Epoch 7/10
# 469/469 [==============================] - 362s 772ms/step - loss: 0.5108 - accuracy: 0.8478 - val_loss: 0.2075 - val_accuracy: 0.9440
# Epoch 8/10
# 469/469 [==============================] - 361s 771ms/step - loss: 0.4841 - accuracy: 0.8548 - val_loss: 0.1918 - val_accuracy: 0.9482
# Epoch 9/10
# 469/469 [==============================] - 365s 779ms/step - loss: 0.4473 - accuracy: 0.8680 - val_loss: 0.1790 - val_accuracy: 0.9521
# Epoch 10/10
# 469/469 [==============================] - 364s 776ms/step - loss: 0.4302 - accuracy: 0.8744 - val_loss: 0.1709 - val_accuracy: 0.9520

# %%
# %load solutions/mnist_conv_architecture.py

# %%
score_conv = model.evaluate(X_test_conv, Y_test_cat, verbose=0)
predict_conv = model.predict(X_test_conv)
print('Test loss:', score_conv[0])
print('Test accuracy:', score_conv[1])
print("Time Running: %.2f seconds" %t_train_conv )

fig=plt.figure(figsize=(7,6))
ax = fig.add_subplot(1,1,1)
ax = sb.heatmap(pd.DataFrame(confusion_matrix(Y_test, predict_conv.argmax(1))), annot=True, fmt="d")

# %% [markdown]
# **Q** Comment the results.
#
# **Q** How to improve them?
